# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy import interpolate as inter
import numpy as np

# %%
fig, ax = plt.subplots()

fig.set_figheight(12)
fig.set_figwidth(20)

plt.rcParams['font.size'] = '20'

ax.set_title('######################',
             fontsize=20,
             loc='left',
             pad=10)
ax.set_ylabel('y',
              fontsize=20)
ax.set_xlabel('x',
              fontsize=20)
ax.grid(which='major',
        color='k')
ax.minorticks_on()
ax.grid(which='minor',
        color='gray',
        linestyle=':')

xLeft = np.array([], float)
xRight = np.array([], float)
psiLeft1 = np.array([], float)
psiLeft2 = np.array([], float)
psiRight1 = np.array([], float)
psiRight2 = np.array([], float)

with open("PsiLeft.csv") as f:
    for line in f.readlines():
        xLeft = np.append(xLeft, float(line.split(' ')[0]))
        psiLeft1 = np.append(psiLeft1, float(line.split(' ')[1]))
        psiLeft2 = np.append(psiLeft2, float(line.split(' ')[2]))

with open("PsiRight.csv") as f:
    for line in f.readlines():
        xRight = np.append(xRight, float(line.split(' ')[0]))
        psiRight1 = np.append(psiRight1, float(line.split(' ')[1]))
        psiRight2 = np.append(psiRight2, float(line.split(' ')[2]))

ax.plot(xRight, psiRight1, linewidth=2, label='#')
ax.plot(xRight, psiRight2, linewidth=2, label='#')
ax.plot(xLeft, psiLeft1, linewidth=2, label='#')
ax.plot(xLeft, psiLeft2, linewidth=2, label='#')

#plt.xlim(6, 8)

ax.scatter(x1, y1, s=3)
ax.scatter(x2, y2, s=3)

# plot X - axis
ax.axhline(y=0, color='k')

# plot Y - axis
ax.axvline(x=0, color='k')
ax.legend()
plt.savefig('Graph.jpg')
plt.show()

# %%
fig, ax = plt.subplots()

fig.set_figheight(12)
fig.set_figwidth(20)

plt.rcParams['font.size'] = '20'

ax.set_title('######################',
             fontsize=20,
             loc='left',
             pad=10)
ax.set_ylabel('y',
              fontsize=20)
ax.set_xlabel('x',
              fontsize=20)
ax.grid(which='major',
        color='k')
ax.minorticks_on()
ax.grid(which='minor',
        color='gray',
        linestyle=':')

x1 = np.array([], float)
x2 = np.array([], float)
y1 = np.array([], float)
y2 = np.array([], float)

with open("func_11.txt") as f:
    for line in f.readlines():
        x1 = np.append(x1, float(line.split(' ')[0]))
        y1 = np.append(y1, float(line.split(' ')[1]))

with open("func_12.txt") as f:
    for line in f.readlines():
        x2 = np.append(x2, float(line.split(' ')[0]))
        y2 = np.append(y2, float(line.split(' ')[1]))

ax.plot(x1, y1, linewidth=2, label='#')
ax.plot(x2, y2, linewidth=2, label='##')

#plt.xlim(6, 8)

ax.scatter(x1, y1, s=3)
ax.scatter(x2, y2, s=3)

# plot X - axis
ax.axhline(y=0, color='k')

# plot Y - axis
ax.axvline(x=0, color='k')
ax.legend()
#plt.savefig('Graph.jpg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [60], in <cell line: 28>()
#      25 y1 = np.array([], float)
#      26 y2 = np.array([], float)
# ---> 28 with open("func_11.txt") as f:
#      29     for line in f.readlines():
#      30         x1 = np.append(x1, float(line.split(' ')[0]))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'func_11.txt'
