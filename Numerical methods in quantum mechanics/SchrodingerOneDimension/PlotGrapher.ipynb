# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy import interpolate as inter
import numpy as np

# %%
fig, ax = plt.subplots()

fig.set_figheight(12)
fig.set_figwidth(20)

plt.rcParams['font.size'] = '20'

ax.set_title('Волновые функции',
             fontsize=20,
             loc='left',
             pad=10)
ax.set_ylabel('y',
              fontsize=20)
ax.set_xlabel('x',
              fontsize=20)
ax.grid(which='major',
        color='k')
ax.minorticks_on()
ax.grid(which='minor',
        color='gray',
        linestyle=':')

x = np.array([], float)
psi1 = np.array([], float)
psi2 = np.array([], float)
psi3 = np.array([], float)
psi4 = np.array([], float)
psi5 = np.array([], float)
psi6 = np.array([], float)
psi7 = np.array([], float)

with open("Psi.csv") as f:
    for line in f.readlines():
        x = np.append(x, float(line.split(' ')[0]))
        psi1 = np.append(psi1, float(line.split(' ')[1]))
        psi2 = np.append(psi2, float(line.split(' ')[2]))
        psi3 = np.append(psi3, float(line.split(' ')[3]))
        psi4 = np.append(psi4, float(line.split(' ')[4]))
        # psi5 = np.append(psi5, float(line.split(' ')[5]))
        # psi6 = np.append(psi6, float(line.split(' ')[6]))
        # psi7 = np.append(psi7, float(line.split(' ')[7]))

ax.plot(x, psi1, linewidth=2, label='Волновая функция 1', color='red')
ax.plot(x, psi2, linewidth=2, label='Волновая функция 2', color='blue')
ax.plot(x, psi3, linewidth=2, label='Волновая функция 3', color='yellow')
ax.plot(x, psi4, linewidth=2, label='Волновая функция 4', color='green')
# ax.plot(x, psi5, linewidth=2, label='Волновая функция 5', color='orange')
# ax.plot(x, psi6, linewidth=2, label='Волновая функция 6', color='magenta')
# ax.plot(x, psi7, linewidth=2, label='Волновая функция 7', color='pink')

# plt.xlim(6, 8)

# ax.scatter(xRight, psiRight1, s=10)
# ax.scatter(xLeft, psiLeft1, s=10)

# plot X - axis
ax.axhline(y=0, color='k')

plt.xlim(-5, 5)

# plot Y - axis
# ax.axvline(x=0, color='k')
# ax.legend()
plt.savefig('Graph.jpg')
plt.show()
