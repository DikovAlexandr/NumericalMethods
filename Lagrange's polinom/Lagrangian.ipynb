# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy import interpolate as inter
import numpy as np

# %%
fig, ax = plt.subplots()

fig.set_figheight(12)
fig.set_figwidth(20)

plt.rcParams['font.size'] = '20'

ax.set_title('Сравнение функции и разложения в полином Лагранжа',
          fontsize = 20,
          loc = 'left',
          pad = 10)
ax.set_ylabel('y',
           fontsize = 20)
ax.set_xlabel('x',
           fontsize = 20)
ax.grid(which='major',
        color = 'k')
ax.minorticks_on()
ax.grid(which='minor',
        color = 'gray',
        linestyle = ':')

x = np.array([], float)
y = np.array([], float)
l = np.array([], float)

with open("plot.csv") as f:
  for line in f.readlines():
    x = np.append(x, float(line.split(' ')[0]))
    l = np.append(l, float(line.split(' ')[1]))
    y = np.append(y, float(line.split(' ')[2]))

ax.plot(x, y, linewidth = 2, label='функция')
ax.plot(x, l, linewidth = 2, label='лагранжиан')

ax.scatter(x, y, s = 3)
ax.scatter(x, l, s = 3)

# plot X - axis    
ax.axhline(y=0, color='k')

# plot Y - axis    
ax.axvline(x=0, color='k')

ax.legend()

plt.savefig('Graph.jpg')

plt.show()
